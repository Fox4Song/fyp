# %%
import os
# os.chdir("drive/MyDrive/fyp/src")

from neural_process.models.np import CNP, LNP
from neural_process.models.attnnp import AttnCNP, AttnLNP

import matplotlib.pyplot as plt
import datetime
import torch
from torch.distributions.kl import kl_divergence

from modules import NLLLoss, ELBOLoss

from data import GPCurvesReader
from utils import plot_functions

TRAINING_ITERATIONS = int(2e5)
PLOT_AFTER = int(2e4)
MAX_CONTEXT_POINTS = 10
torch.manual_seed(0)

# Train dataset
dataset_train = GPCurvesReader(batch_size=64, max_num_context=MAX_CONTEXT_POINTS)
# Test dataset
dataset_test = GPCurvesReader(
    batch_size=100, max_num_context=MAX_CONTEXT_POINTS, testing=True
)

criterion = NLLLoss()

# Model
model = AttnCNP(1, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Training loop
for it in range(TRAINING_ITERATIONS+1):
    # Sample a batch from the training dataset
    data_train = dataset_train.generate_curves()
    context_x, context_y, target_x, target_y, num_targets, _ = data_train

    optimizer.zero_grad()
    dist, z, q_zc, q_zct = model(context_x, context_y, target_x, target_y)
    # log_prob = None if target_y is None else dist.log_prob(target_y)
    # # kl = kl_divergence(q_zct, q_zc)
    # # kl = kl.sum(dim=-1, keepdim=True)
    # # loss = torch.mean(log_prob.squeeze(0) - kl / float(num_targets))
    # loss = -log_prob.mean()
    # loss = criterion(dist, q_zct, q_zc, target_y)
    loss = criterion(dist, target_y)
    loss.backward()
    optimizer.step()

    if it % 1000 == 0:
        print("Iteration: {}, train loss: {}".format(it, loss))

    # Plot and print the loss every PLOT_AFTER iterations
    if it % PLOT_AFTER == 0:
        data_test = dataset_test.generate_curves()
        context_x, context_y, target_x, target_y, num_targets, _ = data_test
        test_dist, test_z, test_q_zc, test_q_zct = model(
            context_x, context_y, target_x, target_y
        )
        pred_y = test_dist.mean.squeeze(0)
        std = test_dist.stddev.squeeze(0)
        # test_log_prob = None if target_y is None else test_dist.log_prob(target_y)
        # # test_kl = kl_divergence(test_q_zct, test_q_zc)
        # # test_kl = test_kl.sum(dim=-1, keepdim=True)
        # # test_loss = -torch.mean(test_log_prob.squeeze(0) - test_kl / float(num_targets))
        # test_loss = -test_log_prob.mean()
        # test_loss = criterion(test_dist, test_q_zct, test_q_zc, target_y)
        test_loss = criterion(test_dist, target_y)

        print(
            "{}, Iteration: {}, Test Loss: {}".format(
                datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), it, test_loss
            )
        )

        plot_functions(
            target_x.detach().numpy(),
            target_y.detach().numpy(),
            context_x.detach().numpy(),
            context_y.detach().numpy(),
            pred_y.detach().numpy(),
            std.detach().numpy(),
        )
        plt.savefig("/content/plots/" + model.__class__.__name__ + "_" + str(it) + ".png")
# Out:
# Iteration: 0, train loss: 67.20084381103516
# 2025-01-07 16:44:35, Iteration: 0, Test Loss: 65.39373016357422
# Iteration: 1000, train loss: 1.6206156015396118
# Iteration: 2000, train loss: 1.130470633506775
# Iteration: 3000, train loss: 1.0491284132003784
# Iteration: 4000, train loss: 0.8062974214553833
# Iteration: 5000, train loss: 0.9569746255874634
# Iteration: 6000, train loss: 0.7146673202514648
# Iteration: 7000, train loss: 0.5041840076446533
# Iteration: 8000, train loss: 0.7151325345039368
# Iteration: 9000, train loss: 0.4439167380332947
# Iteration: 10000, train loss: 0.539853572845459
# Iteration: 11000, train loss: 0.43593552708625793
# Iteration: 12000, train loss: 0.7428064346313477
# Iteration: 13000, train loss: 0.5121549963951111
# Iteration: 14000, train loss: 1.0464695692062378
# Iteration: 15000, train loss: 0.008853131905198097
# Iteration: 16000, train loss: 0.1185082346200943
# Iteration: 17000, train loss: 0.35848721861839294
# Iteration: 18000, train loss: 0.7206456661224365
# Iteration: 19000, train loss: 0.04340705648064613
# Iteration: 20000, train loss: 0.3048386573791504
# 2025-01-07 16:54:17, Iteration: 20000, Test Loss: 0.8525035977363586
# Iteration: 21000, train loss: 0.18941842019557953
# Iteration: 22000, train loss: 0.5653883814811707
# Iteration: 23000, train loss: 0.2484406977891922
# Iteration: 24000, train loss: 0.18762058019638062
# Iteration: 25000, train loss: 0.8292403221130371
# Iteration: 26000, train loss: 0.0787716656923294
# Iteration: 27000, train loss: -0.1416216641664505
# Iteration: 28000, train loss: 0.041742220520973206
# Iteration: 29000, train loss: 0.028229227289557457
# Iteration: 30000, train loss: 0.06635255366563797
# Iteration: 31000, train loss: 0.4586864113807678
# Iteration: 32000, train loss: -0.02458023652434349
# Iteration: 33000, train loss: 0.09426058828830719
# Iteration: 34000, train loss: 0.1050286516547203
# Iteration: 35000, train loss: 0.47127753496170044
# Iteration: 36000, train loss: 0.40442585945129395
# Iteration: 37000, train loss: 0.0259717907756567
# Iteration: 38000, train loss: 0.30625879764556885
# Iteration: 39000, train loss: 0.2599678039550781
# Iteration: 40000, train loss: -0.1317017823457718
# 2025-01-07 17:05:21, Iteration: 40000, Test Loss: 0.9343811273574829
# Iteration: 41000, train loss: 0.23998090624809265
# Iteration: 42000, train loss: 0.46893590688705444
# Iteration: 43000, train loss: -0.2521843910217285
# Iteration: 44000, train loss: -0.2795335650444031
# Iteration: 45000, train loss: 0.3072509765625
# Iteration: 46000, train loss: 0.852001428604126
# Iteration: 47000, train loss: -0.17157307267189026
# Iteration: 48000, train loss: -0.2904171645641327
# Iteration: 49000, train loss: -0.0341884046792984
# Iteration: 50000, train loss: 0.6281546950340271
# Iteration: 51000, train loss: -0.18174298107624054
# Iteration: 52000, train loss: -0.34723174571990967
# Iteration: 53000, train loss: 0.026042837649583817
# Iteration: 54000, train loss: 0.13025033473968506
# Iteration: 55000, train loss: 0.09043958783149719
# Iteration: 56000, train loss: 0.7106754779815674
# Iteration: 57000, train loss: -0.0037225831765681505
# Iteration: 58000, train loss: 0.04964403808116913
# Iteration: 59000, train loss: -0.0864473357796669
# Iteration: 60000, train loss: -0.09471317380666733
# 2025-01-07 17:18:48, Iteration: 60000, Test Loss: 0.6304541230201721
# Iteration: 61000, train loss: -0.16501645743846893
# Iteration: 62000, train loss: -0.2922768294811249
# Iteration: 63000, train loss: 0.09331148862838745
# Iteration: 64000, train loss: 0.024651579558849335
# Iteration: 65000, train loss: 0.04596048593521118
# Iteration: 66000, train loss: -0.22051718831062317
# Iteration: 67000, train loss: -0.009653911925852299
# Iteration: 68000, train loss: 0.7155091166496277
# Iteration: 69000, train loss: -0.12122763693332672
# Iteration: 70000, train loss: -0.24754977226257324
# Iteration: 71000, train loss: -0.10631129145622253
# Iteration: 72000, train loss: -0.3098701238632202
# Iteration: 73000, train loss: 0.2450573593378067
# Iteration: 74000, train loss: -0.0005496452795341611
# Iteration: 75000, train loss: 0.7166789770126343
# Iteration: 76000, train loss: -0.1187032014131546
# Iteration: 77000, train loss: 0.1306832879781723
# Iteration: 78000, train loss: -0.23328809440135956
# Iteration: 79000, train loss: -0.15385594964027405
# Iteration: 80000, train loss: -0.12673188745975494
# 2025-01-07 17:32:39, Iteration: 80000, Test Loss: 0.9136277437210083
# Iteration: 81000, train loss: -0.026337070390582085
# Iteration: 82000, train loss: 0.318203330039978
# Iteration: 83000, train loss: -0.22708433866500854
# Iteration: 84000, train loss: -0.3000575602054596
# Iteration: 85000, train loss: 0.3456486165523529
# Iteration: 86000, train loss: -0.3508308529853821
# Iteration: 87000, train loss: 0.37042081356048584
# Iteration: 88000, train loss: -0.14451955258846283
# Iteration: 89000, train loss: -0.3587503731250763
# Iteration: 90000, train loss: -0.0816534161567688
# Iteration: 91000, train loss: 0.18234311044216156
# Iteration: 92000, train loss: -0.03454766795039177
# Iteration: 93000, train loss: 0.14917698502540588
# Iteration: 94000, train loss: -0.4494175612926483
# Iteration: 95000, train loss: -0.30552804470062256
# Iteration: 96000, train loss: 0.06247517094016075
# Iteration: 97000, train loss: -0.3773868978023529
# Iteration: 98000, train loss: 0.4627045691013336
# Iteration: 99000, train loss: -0.27115577459335327
# Iteration: 100000, train loss: 0.3807206451892853
# 2025-01-07 17:46:36, Iteration: 100000, Test Loss: 0.5787196159362793
# Iteration: 101000, train loss: 0.33948564529418945
# Iteration: 102000, train loss: 0.07996048033237457
# Iteration: 103000, train loss: -0.14082001149654388
# Iteration: 104000, train loss: -0.3156238794326782
# Iteration: 105000, train loss: 0.26843252778053284
# Iteration: 106000, train loss: 0.37976622581481934
# Iteration: 107000, train loss: -0.28831642866134644
# Iteration: 108000, train loss: -0.18506167829036713
# Iteration: 109000, train loss: -0.17124015092849731
# Iteration: 110000, train loss: -0.5342875123023987
# Iteration: 111000, train loss: -0.07033564895391464
# Iteration: 112000, train loss: 0.2683566212654114
# Iteration: 113000, train loss: 0.2759822607040405
# Iteration: 114000, train loss: -0.26633593440055847
# Iteration: 115000, train loss: -0.32287248969078064
# Iteration: 116000, train loss: -0.0723608136177063
# Iteration: 117000, train loss: -0.11263453960418701
# Iteration: 118000, train loss: 0.2332167625427246
# Iteration: 119000, train loss: 0.42262399196624756
# Iteration: 120000, train loss: 0.1569625437259674
# 2025-01-07 18:00:44, Iteration: 120000, Test Loss: 0.7184038162231445
# Iteration: 121000, train loss: 0.5202857255935669
# Iteration: 122000, train loss: -0.08930177986621857
# Iteration: 123000, train loss: 0.23337145149707794
# Iteration: 124000, train loss: 0.07469118386507034
# Iteration: 125000, train loss: -0.4901663064956665
# Iteration: 126000, train loss: -0.05455898120999336
# Iteration: 127000, train loss: 0.025959253311157227
# Iteration: 128000, train loss: -0.367962509393692
# Iteration: 129000, train loss: -0.11082559078931808
# Iteration: 130000, train loss: -0.32883626222610474
# Iteration: 131000, train loss: -0.11181378364562988
# Iteration: 132000, train loss: -0.2688702642917633
# Iteration: 133000, train loss: 0.09279408305883408
# Iteration: 134000, train loss: 0.10923673957586288
# Iteration: 135000, train loss: -0.21226182579994202
# Iteration: 136000, train loss: -0.14795315265655518
# Iteration: 137000, train loss: 0.011070662178099155
# Iteration: 138000, train loss: -0.2787320911884308
# Iteration: 139000, train loss: -0.5562281608581543
# Iteration: 140000, train loss: 0.06635703146457672
# 2025-01-07 18:14:52, Iteration: 140000, Test Loss: 0.6713336110115051
# Iteration: 141000, train loss: -0.025197505950927734
# Iteration: 142000, train loss: -0.04668036475777626
# Iteration: 143000, train loss: -0.23090744018554688
# Iteration: 144000, train loss: -0.33977454900741577
# Iteration: 145000, train loss: -0.2623679041862488
# Iteration: 146000, train loss: 0.3119874596595764
# Iteration: 147000, train loss: -0.5355585217475891
# Iteration: 148000, train loss: -0.10649202018976212
# Iteration: 149000, train loss: -0.20719054341316223
# Iteration: 150000, train loss: -0.15567855536937714
# Iteration: 151000, train loss: -0.0243233572691679
# Iteration: 152000, train loss: 0.4192449152469635
# Iteration: 153000, train loss: 0.5080800652503967
# Iteration: 154000, train loss: -0.485812783241272
# Iteration: 155000, train loss: 0.1884140819311142
# Iteration: 156000, train loss: -0.1684459149837494
# Iteration: 157000, train loss: -0.2574157118797302
# Iteration: 158000, train loss: 0.05947659909725189
# Iteration: 159000, train loss: 0.36249351501464844
# Iteration: 160000, train loss: -0.530586302280426
# 2025-01-07 18:28:45, Iteration: 160000, Test Loss: 1.02094566822052
# Iteration: 161000, train loss: -0.6280679106712341
# Iteration: 162000, train loss: -0.11613057553768158
# Iteration: 163000, train loss: 0.2554960250854492
# Iteration: 164000, train loss: 0.1825949102640152
# Iteration: 165000, train loss: 0.15322497487068176
# Iteration: 166000, train loss: -0.5706815123558044
# Iteration: 167000, train loss: -0.15650051832199097
# Iteration: 168000, train loss: 0.29840287566185
# Iteration: 169000, train loss: 0.5426656007766724
# Iteration: 170000, train loss: -0.41612690687179565
# Iteration: 171000, train loss: 0.3350529968738556
# Iteration: 172000, train loss: 0.11564696580171585
# Iteration: 173000, train loss: 0.21820367872714996
# Iteration: 174000, train loss: -0.09705501049757004
# Iteration: 175000, train loss: -0.15904980897903442
# Iteration: 176000, train loss: 0.21867810189723969
# Iteration: 177000, train loss: -0.2602292001247406
# Iteration: 178000, train loss: 0.07710801064968109
# Iteration: 179000, train loss: 0.1923779398202896
# Iteration: 180000, train loss: -0.053729861974716187
# 2025-01-07 18:42:58, Iteration: 180000, Test Loss: 0.42742791771888733
# Iteration: 181000, train loss: 0.13198600709438324
# Iteration: 182000, train loss: -0.5028641819953918
# Iteration: 183000, train loss: -0.09622105211019516
# Iteration: 184000, train loss: 0.0037488341331481934
# Iteration: 185000, train loss: 0.02378375083208084
# Iteration: 186000, train loss: -0.34073951840400696
# Iteration: 187000, train loss: 0.2849210500717163
# Iteration: 188000, train loss: -0.3639355003833771
# Iteration: 189000, train loss: 0.12408280372619629
# Iteration: 190000, train loss: -0.4362632632255554
# Iteration: 191000, train loss: 0.1336156725883484
# Iteration: 192000, train loss: -0.5749759674072266
# Iteration: 193000, train loss: -0.2949986159801483
# Iteration: 194000, train loss: 0.02492954581975937
# Iteration: 195000, train loss: 0.19416776299476624
# Iteration: 196000, train loss: 0.11034692823886871
# Iteration: 197000, train loss: -0.48527854681015015
# Iteration: 198000, train loss: 0.51469486951828
# Iteration: 199000, train loss: -0.343413770198822
# Iteration: 200000, train loss: -0.26972439885139465
# 2025-01-07 18:57:05, Iteration: 200000, Test Loss: 0.7589609622955322

# %%
torch.save(model.state_dict(), "/content/models/" + model.__class__.__name__ + ".pt")
