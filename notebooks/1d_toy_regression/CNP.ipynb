# %%
import os
# os.chdir("drive/MyDrive/fyp/src")

from neural_process.models.np import CNP, LNP
from neural_process.models.attnnp import AttnCNP, AttnLNP

import datetime
import torch
from torch.distributions.kl import kl_divergence

from modules import NLLLoss, ELBOLoss

from data import GPCurvesReader
from utils import plot_functions

TRAINING_ITERATIONS = int(2e5)
PLOT_AFTER = int(2e4)
MAX_CONTEXT_POINTS = 10
torch.manual_seed(0)

# Train dataset
dataset_train = GPCurvesReader(batch_size=64, max_num_context=MAX_CONTEXT_POINTS)
# Test dataset
dataset_test = GPCurvesReader(
    batch_size=100, max_num_context=MAX_CONTEXT_POINTS, testing=True
)

criterion = NLLLoss()

# Model
model = CNP(1, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Training loop
for it in range(TRAINING_ITERATIONS+1):
    # Sample a batch from the training dataset
    data_train = dataset_train.generate_curves()
    context_x, context_y, target_x, target_y, num_targets, _ = data_train

    optimizer.zero_grad()
    dist, z, q_zc, q_zct = model(context_x, context_y, target_x, target_y)
    # loss = criterion(dist, q_zct, q_zc, target_y)
    loss = criterion(dist, target_y)
    loss.backward()
    optimizer.step()

    if it % 1000 == 0:
        print("Iteration: {}, train loss: {}".format(it, loss))

    # Plot and print the loss every PLOT_AFTER iterations
    if it % PLOT_AFTER == 0:
        data_test = dataset_test.generate_curves()
        context_x, context_y, target_x, target_y, num_targets, _ = data_test
        test_dist, test_z, test_q_zc, test_q_zct = model(
            context_x, context_y, target_x, target_y
        )
        pred_y = test_dist.mean.mean(0)
        std = test_dist.stddev.mean(0)
        # test_loss = criterion(test_dist, test_q_zct, test_q_zc, target_y)
        test_loss = criterion(test_dist, target_y)

        print(
            "{}, Iteration: {}, Test Loss: {}".format(
                datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), it, test_loss
            )
        )

        plot_functions(
            target_x.detach().numpy(),
            target_y.detach().numpy(),
            context_x.detach().numpy(),
            context_y.detach().numpy(),
            pred_y.detach().numpy(),
            std.detach().numpy(),
            '/content/plots/' + model.__class__.__name__ + '-' + str(it) + '.png',
        )
# Out:
# Iteration: 0, train loss: 7.88976526260376
# 2025-01-14 14:47:28, Iteration: 0, Test Loss: 3.706331968307495
# Iteration: 1000, train loss: 1.0981898307800293
# Iteration: 2000, train loss: 1.0532174110412598
# Iteration: 3000, train loss: 1.0261776447296143
# Iteration: 4000, train loss: 1.058912992477417
# Iteration: 5000, train loss: 0.897291362285614
# Iteration: 6000, train loss: 0.8966406583786011
# Iteration: 7000, train loss: 0.8829212188720703
# Iteration: 8000, train loss: 0.7314538955688477
# Iteration: 9000, train loss: 0.8604840040206909
# Iteration: 10000, train loss: 1.0789662599563599
# Iteration: 11000, train loss: 0.7230093479156494
# Iteration: 12000, train loss: 0.6494589447975159
# Iteration: 13000, train loss: 0.7254657745361328
# Iteration: 14000, train loss: 0.5511795878410339
# Iteration: 15000, train loss: 0.5690416693687439
# Iteration: 16000, train loss: 0.4766150116920471
# Iteration: 17000, train loss: 0.6420256495475769
# Iteration: 18000, train loss: 0.6187961101531982
# Iteration: 19000, train loss: 0.948655903339386
# Iteration: 20000, train loss: 0.6471334099769592
# 2025-01-14 14:50:31, Iteration: 20000, Test Loss: 0.8969824314117432
# Iteration: 21000, train loss: 0.6205683946609497
# Iteration: 22000, train loss: 0.5931249856948853
# Iteration: 23000, train loss: 0.47534966468811035
# Iteration: 24000, train loss: 0.9778562188148499
# Iteration: 25000, train loss: 0.4457542300224304
# Iteration: 26000, train loss: 0.508807361125946
# Iteration: 27000, train loss: 0.543166995048523
# Iteration: 28000, train loss: 0.7544485926628113
# Iteration: 29000, train loss: 0.6241481900215149
# Iteration: 30000, train loss: 0.3992486298084259
# Iteration: 31000, train loss: 0.7435974478721619
# Iteration: 32000, train loss: 0.60838782787323
# Iteration: 33000, train loss: 0.49857765436172485
# Iteration: 34000, train loss: 0.3605269193649292
# Iteration: 35000, train loss: 0.6765165328979492
# Iteration: 36000, train loss: 0.42418548464775085
# Iteration: 37000, train loss: 0.3807486593723297
# Iteration: 38000, train loss: 0.28493738174438477
# Iteration: 39000, train loss: 0.8077960014343262
# Iteration: 40000, train loss: 0.36694130301475525
# 2025-01-14 14:53:34, Iteration: 40000, Test Loss: 0.7109454870223999
# Iteration: 41000, train loss: 0.5446822643280029
# Iteration: 42000, train loss: 0.41120222210884094
# Iteration: 43000, train loss: 0.5626654624938965
# Iteration: 44000, train loss: 0.416881799697876
# Iteration: 45000, train loss: 0.48931270837783813
# Iteration: 46000, train loss: 0.4298464357852936
# Iteration: 47000, train loss: 0.42439553141593933
# Iteration: 48000, train loss: 0.29975011944770813
# Iteration: 49000, train loss: 0.2529663145542145
# Iteration: 50000, train loss: 0.32315266132354736
# Iteration: 51000, train loss: 0.631561279296875
# Iteration: 52000, train loss: 0.26129472255706787
# Iteration: 53000, train loss: 0.2842586934566498
# Iteration: 54000, train loss: 0.2571350336074829
# Iteration: 55000, train loss: 0.471567839384079
# Iteration: 56000, train loss: 0.41419845819473267
# Iteration: 57000, train loss: 0.3171924352645874
# Iteration: 58000, train loss: 0.4968613088130951
# Iteration: 59000, train loss: 0.3261677622795105
# Iteration: 60000, train loss: 0.1144595593214035
# 2025-01-14 14:56:41, Iteration: 60000, Test Loss: 0.9422776103019714
# Iteration: 61000, train loss: 0.2682332992553711
# Iteration: 62000, train loss: 0.42281314730644226
# Iteration: 63000, train loss: 0.29292619228363037
# Iteration: 64000, train loss: 0.11813538521528244
# Iteration: 65000, train loss: 0.5165221691131592
# Iteration: 66000, train loss: 0.45667266845703125
# Iteration: 67000, train loss: 0.5181776285171509
# Iteration: 68000, train loss: 0.707460343837738
# Iteration: 69000, train loss: 0.29624849557876587
# Iteration: 70000, train loss: 0.39241892099380493
# Iteration: 71000, train loss: 0.24333368241786957
# Iteration: 72000, train loss: 0.7919842004776001
# Iteration: 73000, train loss: 0.42064952850341797
# Iteration: 74000, train loss: 0.23335790634155273
# Iteration: 75000, train loss: 0.2923358678817749
# Iteration: 76000, train loss: 0.3470391035079956
# Iteration: 77000, train loss: 0.25552767515182495
# Iteration: 78000, train loss: 0.3376653790473938
# Iteration: 79000, train loss: 0.14592377841472626
# Iteration: 80000, train loss: 0.10174299031496048
# 2025-01-14 14:59:45, Iteration: 80000, Test Loss: 0.7336288690567017
# Iteration: 81000, train loss: 0.3774029612541199
# Iteration: 82000, train loss: 0.32332298159599304
# Iteration: 83000, train loss: 0.1593565046787262
# Iteration: 84000, train loss: 0.34074944257736206
# Iteration: 85000, train loss: 0.43504002690315247
# Iteration: 86000, train loss: 0.19428811967372894
# Iteration: 87000, train loss: 0.13117098808288574
# Iteration: 88000, train loss: 0.7308149337768555
# Iteration: 89000, train loss: -0.018200965598225594
# Iteration: 90000, train loss: 0.27169278264045715
# Iteration: 91000, train loss: 0.05703159049153328
# Iteration: 92000, train loss: 0.12578816711902618
# Iteration: 93000, train loss: 0.2609715461730957
# Iteration: 94000, train loss: 0.4090551733970642
# Iteration: 95000, train loss: 0.23044416308403015
# Iteration: 96000, train loss: 0.5063127875328064
# Iteration: 97000, train loss: 0.6665544509887695
# Iteration: 98000, train loss: 0.1692146360874176
# Iteration: 99000, train loss: 0.15031711757183075
# Iteration: 100000, train loss: 0.3784738779067993
# 2025-01-14 15:02:47, Iteration: 100000, Test Loss: 0.6881362795829773
# Iteration: 101000, train loss: 0.20973339676856995
# Iteration: 102000, train loss: 0.32773739099502563
# Iteration: 103000, train loss: 0.1166088804602623
# Iteration: 104000, train loss: 0.5820127129554749
# Iteration: 105000, train loss: 0.605984628200531
# Iteration: 106000, train loss: 0.0043566362001001835
# Iteration: 107000, train loss: 0.22239133715629578
# Iteration: 108000, train loss: 0.3688162565231323
# Iteration: 109000, train loss: 0.18531660735607147
# Iteration: 110000, train loss: 0.18569131195545197
# Iteration: 111000, train loss: 0.07080435752868652
# Iteration: 112000, train loss: 0.15720275044441223
# Iteration: 113000, train loss: 0.13107818365097046
# Iteration: 114000, train loss: 0.0990503579378128
# Iteration: 115000, train loss: 0.17369239032268524
# Iteration: 116000, train loss: -0.035681210458278656
# Iteration: 117000, train loss: -0.09468363970518112
# Iteration: 118000, train loss: 0.5390592813491821
# Iteration: 119000, train loss: 0.17595122754573822
# Iteration: 120000, train loss: 0.1685667783021927
# 2025-01-14 15:05:50, Iteration: 120000, Test Loss: 0.5076123476028442
# Iteration: 121000, train loss: 0.16861799359321594
# Iteration: 122000, train loss: -0.08157408982515335
# Iteration: 123000, train loss: 0.5697066783905029
# Iteration: 124000, train loss: 0.24698874354362488
# Iteration: 125000, train loss: 0.26690319180488586
# Iteration: 126000, train loss: 0.5794368386268616
# Iteration: 127000, train loss: 0.02713116630911827
# Iteration: 128000, train loss: 0.38821926712989807
# Iteration: 129000, train loss: 0.49785465002059937
# Iteration: 130000, train loss: 0.24369677901268005
# Iteration: 131000, train loss: 0.27170002460479736
# Iteration: 132000, train loss: -0.051975298672914505
# Iteration: 133000, train loss: 0.24727781116962433
# Iteration: 134000, train loss: -0.02449122630059719
# Iteration: 135000, train loss: 0.15130342543125153
# Iteration: 136000, train loss: 0.10042119026184082
# Iteration: 137000, train loss: 0.03295724093914032
# Iteration: 138000, train loss: 0.036766842007637024
# Iteration: 139000, train loss: 0.23437519371509552
# Iteration: 140000, train loss: -0.04032464697957039
# 2025-01-14 15:08:50, Iteration: 140000, Test Loss: 0.6191167235374451
# Iteration: 141000, train loss: -0.041379377245903015
# Iteration: 142000, train loss: 0.2497282773256302
# Iteration: 143000, train loss: 0.08654390275478363
# Iteration: 144000, train loss: -0.08988756686449051
# Iteration: 145000, train loss: 0.14737087488174438
# Iteration: 146000, train loss: 0.48068568110466003
# Iteration: 147000, train loss: 0.10666860640048981
# Iteration: 148000, train loss: -0.04730478674173355
# Iteration: 149000, train loss: 0.24154287576675415
# Iteration: 150000, train loss: 0.2062218189239502
# Iteration: 151000, train loss: 0.5998872518539429
# Iteration: 152000, train loss: -0.03799113631248474
# Iteration: 153000, train loss: -0.0896938145160675
# Iteration: 154000, train loss: -0.06750062108039856
# Iteration: 155000, train loss: 0.554044783115387
# Iteration: 156000, train loss: 0.21434535086154938
# Iteration: 157000, train loss: 0.1055828258395195
# Iteration: 158000, train loss: -0.01811421476304531
# Iteration: 159000, train loss: 0.5290778875350952
# Iteration: 160000, train loss: 0.05565900728106499
# 2025-01-14 15:11:51, Iteration: 160000, Test Loss: 0.9334978461265564
# Iteration: 161000, train loss: 0.0517510324716568
# Iteration: 162000, train loss: 0.08293968439102173
# Iteration: 163000, train loss: 0.1989925652742386
# Iteration: 164000, train loss: 0.21034929156303406
# Iteration: 165000, train loss: -0.08235494047403336
# Iteration: 166000, train loss: 0.1943598985671997
# Iteration: 167000, train loss: 0.11649908870458603
# Iteration: 168000, train loss: -0.01650019735097885
# Iteration: 169000, train loss: 0.22922870516777039
# Iteration: 170000, train loss: 0.133999764919281
# Iteration: 171000, train loss: 0.14659146964550018
# Iteration: 172000, train loss: 0.21980391442775726
# Iteration: 173000, train loss: 0.19888675212860107
# Iteration: 174000, train loss: 0.05567480996251106
# Iteration: 175000, train loss: -0.06648190319538116
# Iteration: 176000, train loss: 0.1493517905473709
# Iteration: 177000, train loss: -0.2639724314212799
# Iteration: 178000, train loss: 0.061363156884908676
# Iteration: 179000, train loss: 0.48091888427734375
# Iteration: 180000, train loss: 0.05644261837005615
# 2025-01-14 15:14:51, Iteration: 180000, Test Loss: 0.5130423903465271
# Iteration: 181000, train loss: 0.20087581872940063
# Iteration: 182000, train loss: 0.15924155712127686
# Iteration: 183000, train loss: 0.2126021385192871
# Iteration: 184000, train loss: -0.05639892444014549
# Iteration: 185000, train loss: 0.7186660766601562
# Iteration: 186000, train loss: -0.0941738560795784
# Iteration: 187000, train loss: 0.47880953550338745
# Iteration: 188000, train loss: 0.06473121047019958
# Iteration: 189000, train loss: 0.5123522877693176
# Iteration: 190000, train loss: 0.687222421169281
# Iteration: 191000, train loss: 0.10382156074047089
# Iteration: 192000, train loss: 0.42469078302383423
# Iteration: 193000, train loss: 0.05089281126856804
# Iteration: 194000, train loss: 0.44742491841316223
# Iteration: 195000, train loss: 0.16171588003635406
# Iteration: 196000, train loss: 0.051058948040008545
# Iteration: 197000, train loss: 0.3769192695617676
# Iteration: 198000, train loss: -0.06575091183185577
# Iteration: 199000, train loss: 0.07030823826789856
# Iteration: 200000, train loss: 0.09943027049303055
# 2025-01-14 15:17:54, Iteration: 200000, Test Loss: 0.4643816351890564

# %%
torch.save(model.state_dict(), "/content/models/" + model.__class__.__name__ + ".pt")
