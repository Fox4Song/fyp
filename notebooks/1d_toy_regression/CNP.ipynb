# %%
import os
# os.chdir("drive/MyDrive/fyp/src")

from neural_process.models.np import CNP, LNP
from neural_process.models.attnnp import AttnCNP, AttnLNP

import matplotlib.pyplot as plt
import datetime
import torch
from torch.distributions.kl import kl_divergence

from modules import NLLLoss, ELBOLoss

from data import GPCurvesReader
from utils import plot_functions

TRAINING_ITERATIONS = int(2e5)
PLOT_AFTER = int(2e4)
MAX_CONTEXT_POINTS = 10
torch.manual_seed(0)

# Train dataset
dataset_train = GPCurvesReader(batch_size=64, max_num_context=MAX_CONTEXT_POINTS)
# Test dataset
dataset_test = GPCurvesReader(
    batch_size=100, max_num_context=MAX_CONTEXT_POINTS, testing=True
)

criterion = NLLLoss()

# Model
model = CNP(1, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Training loop
for it in range(TRAINING_ITERATIONS+1):
    # Sample a batch from the training dataset
    data_train = dataset_train.generate_curves()
    context_x, context_y, target_x, target_y, num_targets, _ = data_train

    optimizer.zero_grad()
    dist, z, q_zc, q_zct = model(context_x, context_y, target_x, target_y)
    # log_prob = None if target_y is None else dist.log_prob(target_y)
    # # kl = kl_divergence(q_zct, q_zc)
    # # kl = kl.sum(dim=-1, keepdim=True)
    # # loss = torch.mean(log_prob.squeeze(0) - kl / float(num_targets))
    # loss = -log_prob.mean()
    # loss = criterion(dist, q_zct, q_zc, target_y)
    loss = criterion(dist, target_y)
    loss.backward()
    optimizer.step()

    if it % 1000 == 0:
        print("Iteration: {}, train loss: {}".format(it, loss))

    # Plot and print the loss every PLOT_AFTER iterations
    if it % PLOT_AFTER == 0:
        data_test = dataset_test.generate_curves()
        context_x, context_y, target_x, target_y, num_targets, _ = data_test
        test_dist, test_z, test_q_zc, test_q_zct = model(
            context_x, context_y, target_x, target_y
        )
        pred_y = test_dist.mean.squeeze(0)
        std = test_dist.stddev.squeeze(0)
        # test_log_prob = None if target_y is None else test_dist.log_prob(target_y)
        # # test_kl = kl_divergence(test_q_zct, test_q_zc)
        # # test_kl = test_kl.sum(dim=-1, keepdim=True)
        # # test_loss = -torch.mean(test_log_prob.squeeze(0) - test_kl / float(num_targets))
        # test_loss = -test_log_prob.mean()
        # test_loss = criterion(test_dist, test_q_zct, test_q_zc, target_y)
        test_loss = criterion(test_dist, target_y)

        print(
            "{}, Iteration: {}, Test Loss: {}".format(
                datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), it, test_loss
            )
        )

        plot_functions(
            target_x.detach().numpy(),
            target_y.detach().numpy(),
            context_x.detach().numpy(),
            context_y.detach().numpy(),
            pred_y.detach().numpy(),
            std.detach().numpy(),
        )
# Out:
# Iteration: 0, train loss: 13.475523948669434
# 2025-01-08 11:49:41, Iteration: 0, Test Loss: 9.174439430236816
# Iteration: 1000, train loss: 1.3017382621765137
# Iteration: 2000, train loss: 1.2366598844528198
# Iteration: 3000, train loss: 1.0155000686645508
# Iteration: 4000, train loss: 1.0687384605407715
# Iteration: 5000, train loss: 1.1386148929595947
# Iteration: 6000, train loss: 0.8995859026908875
# Iteration: 7000, train loss: 0.9438828825950623
# Iteration: 8000, train loss: 0.9955570101737976
# Iteration: 9000, train loss: 1.0021436214447021
# Iteration: 10000, train loss: 0.9796513319015503
# Iteration: 11000, train loss: 0.8832234740257263
# Iteration: 12000, train loss: 0.9312970042228699
# Iteration: 13000, train loss: 0.9837379455566406
# Iteration: 14000, train loss: 0.9674208164215088
# Iteration: 15000, train loss: 0.8783812522888184
# Iteration: 16000, train loss: 0.7641852498054504
# Iteration: 17000, train loss: 0.6515749096870422
# Iteration: 18000, train loss: 0.7633863091468811
# Iteration: 19000, train loss: 0.8123239278793335
# Iteration: 20000, train loss: 0.6213457584381104
# 2025-01-08 11:53:53, Iteration: 20000, Test Loss: 0.908473551273346
# Iteration: 21000, train loss: 0.8960291743278503
# Iteration: 22000, train loss: 0.8061234951019287
# Iteration: 23000, train loss: 0.7845389246940613
# Iteration: 24000, train loss: 0.7669229507446289
# Iteration: 25000, train loss: 0.7118666172027588
# Iteration: 26000, train loss: 0.6321704387664795
# Iteration: 27000, train loss: 0.8550593256950378
# Iteration: 28000, train loss: 0.6999189853668213
# Iteration: 29000, train loss: 0.49481725692749023
# Iteration: 30000, train loss: 0.5588825941085815
# Iteration: 31000, train loss: 0.5688998699188232
# Iteration: 32000, train loss: 0.7309325933456421
# Iteration: 33000, train loss: 0.5611511468887329
# Iteration: 34000, train loss: 0.5582739114761353
# Iteration: 35000, train loss: 0.9683444499969482
# Iteration: 36000, train loss: 0.6648809313774109
# Iteration: 37000, train loss: 0.6039105653762817
# Iteration: 38000, train loss: 0.533833920955658
# Iteration: 39000, train loss: 0.5974565744400024
# Iteration: 40000, train loss: 0.6038175225257874
# 2025-01-08 11:58:08, Iteration: 40000, Test Loss: 0.7455976605415344
# Iteration: 41000, train loss: 0.5757230520248413
# Iteration: 42000, train loss: 0.5731508731842041
# Iteration: 43000, train loss: 0.38815248012542725
# Iteration: 44000, train loss: 0.6892967820167542
# Iteration: 45000, train loss: 0.4553866982460022
# Iteration: 46000, train loss: 0.5762536525726318
# Iteration: 47000, train loss: 0.5109871625900269
# Iteration: 48000, train loss: 0.48442211747169495
# Iteration: 49000, train loss: 0.5165141820907593
# Iteration: 50000, train loss: 0.4954516589641571
# Iteration: 51000, train loss: 0.643135666847229
# Iteration: 52000, train loss: 0.4850570559501648
# Iteration: 53000, train loss: 0.5012874007225037
# Iteration: 54000, train loss: 0.4720540940761566
# Iteration: 55000, train loss: 0.44779524207115173
# Iteration: 56000, train loss: 0.380354642868042
# Iteration: 57000, train loss: 0.34223124384880066
# Iteration: 58000, train loss: 0.5657246708869934
# Iteration: 59000, train loss: 0.7077345848083496
# Iteration: 60000, train loss: 0.4227319657802582
# 2025-01-08 12:02:24, Iteration: 60000, Test Loss: 0.9719050526618958
# Iteration: 61000, train loss: 0.24170638620853424
# Iteration: 62000, train loss: 0.535121500492096
# Iteration: 63000, train loss: 0.47711247205734253
# Iteration: 64000, train loss: 0.6614962220191956
# Iteration: 65000, train loss: 0.6992826461791992
# Iteration: 66000, train loss: 0.3822181820869446
# Iteration: 67000, train loss: 0.8132537603378296
# Iteration: 68000, train loss: 0.5905893445014954
# Iteration: 69000, train loss: 0.3811922073364258
# Iteration: 70000, train loss: 0.4026384651660919
# Iteration: 71000, train loss: 0.35926884412765503
# Iteration: 72000, train loss: 0.593784749507904
# Iteration: 73000, train loss: 0.34925463795661926
# Iteration: 74000, train loss: 0.5086551904678345
# Iteration: 75000, train loss: 0.5542476773262024
# Iteration: 76000, train loss: 0.931689441204071
# Iteration: 77000, train loss: 0.31312280893325806
# Iteration: 78000, train loss: 0.6241570115089417
# Iteration: 79000, train loss: 0.5297724604606628
# Iteration: 80000, train loss: 0.26079103350639343
# 2025-01-08 12:06:41, Iteration: 80000, Test Loss: 1.225983738899231
# Iteration: 81000, train loss: 0.48073264956474304
# Iteration: 82000, train loss: 0.3320912718772888
# Iteration: 83000, train loss: 0.4964154064655304
# Iteration: 84000, train loss: 0.40551891922950745
# Iteration: 85000, train loss: 0.36904361844062805
# Iteration: 86000, train loss: 0.28055548667907715
# Iteration: 87000, train loss: 0.40926092863082886
# Iteration: 88000, train loss: 0.2988344132900238
# Iteration: 89000, train loss: 0.11650867015123367
# Iteration: 90000, train loss: 0.391814649105072
# Iteration: 91000, train loss: 0.39544782042503357
# Iteration: 92000, train loss: 0.6058309078216553
# Iteration: 93000, train loss: 0.5432193279266357
# Iteration: 94000, train loss: 0.3810034692287445
# Iteration: 95000, train loss: 0.43389877676963806
# Iteration: 96000, train loss: 0.3886229693889618
# Iteration: 97000, train loss: 0.18831594288349152
# Iteration: 98000, train loss: 0.5167447924613953
# Iteration: 99000, train loss: 0.3666130304336548
# Iteration: 100000, train loss: 0.4555048644542694
# 2025-01-08 12:11:03, Iteration: 100000, Test Loss: 0.90069580078125
# Iteration: 101000, train loss: 0.3913358151912689
# Iteration: 102000, train loss: 0.5670202374458313
# Iteration: 103000, train loss: 0.6406105160713196
# Iteration: 104000, train loss: 0.7291648983955383
# Iteration: 105000, train loss: 0.5821203589439392
# Iteration: 106000, train loss: 0.416898638010025
# Iteration: 107000, train loss: 0.4193650484085083
# Iteration: 108000, train loss: 0.4797861874103546
# Iteration: 109000, train loss: 0.7553145289421082
# Iteration: 110000, train loss: 0.4401390850543976
# Iteration: 111000, train loss: 0.6094432473182678
# Iteration: 112000, train loss: 0.4537394046783447
# Iteration: 113000, train loss: 0.36563900113105774
# Iteration: 114000, train loss: 0.2190769761800766
# Iteration: 115000, train loss: 0.7327657341957092
# Iteration: 116000, train loss: 0.5932806730270386
# Iteration: 117000, train loss: 0.3833528161048889
# Iteration: 118000, train loss: 0.4974205195903778
# Iteration: 119000, train loss: 0.4179421365261078
# Iteration: 120000, train loss: 0.1203065738081932
# 2025-01-08 12:15:25, Iteration: 120000, Test Loss: 0.9524632692337036
# Iteration: 121000, train loss: 0.33374717831611633
# Iteration: 122000, train loss: 0.23628763854503632
# Iteration: 123000, train loss: 0.7635772228240967
# Iteration: 124000, train loss: 0.3065362870693207
# Iteration: 125000, train loss: 0.6394238471984863
# Iteration: 126000, train loss: 0.24687819182872772
# Iteration: 127000, train loss: 0.16092340648174286
# Iteration: 128000, train loss: 0.2948247194290161
# Iteration: 129000, train loss: 0.26136747002601624
# Iteration: 130000, train loss: 0.6986866593360901
# Iteration: 131000, train loss: 0.2139182835817337
# Iteration: 132000, train loss: 0.42436549067497253
# Iteration: 133000, train loss: 0.1850629448890686
# Iteration: 134000, train loss: 0.33629560470581055
# Iteration: 135000, train loss: 0.3198629319667816
# Iteration: 136000, train loss: 0.33296844363212585
# Iteration: 137000, train loss: 0.34035372734069824
# Iteration: 138000, train loss: 0.6467349529266357
# Iteration: 139000, train loss: 0.31425344944000244
# Iteration: 140000, train loss: 0.6081783771514893
# 2025-01-08 12:19:50, Iteration: 140000, Test Loss: 1.0075628757476807
# Iteration: 141000, train loss: 0.23943129181861877
# Iteration: 142000, train loss: 0.09803078323602676
# Iteration: 143000, train loss: 0.37587177753448486
# Iteration: 144000, train loss: 0.46312928199768066
# Iteration: 145000, train loss: 0.36845770478248596
# Iteration: 146000, train loss: 0.18051685392856598
# Iteration: 147000, train loss: 0.10727472603321075
# Iteration: 148000, train loss: 0.701441764831543
# Iteration: 149000, train loss: 0.5456938147544861
# Iteration: 150000, train loss: 0.64485102891922
# Iteration: 151000, train loss: 0.2755495011806488
# Iteration: 152000, train loss: 0.34560978412628174
# Iteration: 153000, train loss: 0.23935501277446747
# Iteration: 154000, train loss: 0.28638309240341187
# Iteration: 155000, train loss: 0.16413263976573944
# Iteration: 156000, train loss: 0.3665695786476135
# Iteration: 157000, train loss: 0.18549507856369019
# Iteration: 158000, train loss: 0.21479485929012299
# Iteration: 159000, train loss: 0.3852968215942383
# Iteration: 160000, train loss: 0.24240846931934357
# 2025-01-08 12:24:16, Iteration: 160000, Test Loss: 0.9584205150604248
# Iteration: 161000, train loss: 0.15070852637290955
# Iteration: 162000, train loss: 0.1573447436094284
# Iteration: 163000, train loss: 0.5623255372047424
# Iteration: 164000, train loss: 0.21530109643936157
# Iteration: 165000, train loss: 0.352115273475647
# Iteration: 166000, train loss: 0.11037454009056091
# Iteration: 167000, train loss: 0.5829817056655884
# Iteration: 168000, train loss: 0.09485288709402084
# Iteration: 169000, train loss: 0.6466277241706848
# Iteration: 170000, train loss: 0.43413612246513367
# Iteration: 171000, train loss: 0.11291040480136871
# Iteration: 172000, train loss: 0.23872829973697662
# Iteration: 173000, train loss: 0.1168283149600029
# Iteration: 174000, train loss: 0.7784022688865662
# Iteration: 175000, train loss: 0.18600068986415863
# Iteration: 176000, train loss: 0.314445436000824
# Iteration: 177000, train loss: 0.4199875295162201
# Iteration: 178000, train loss: 0.46238189935684204
# Iteration: 179000, train loss: 0.3910193145275116
# Iteration: 180000, train loss: 0.7503723502159119
# 2025-01-08 12:28:43, Iteration: 180000, Test Loss: 0.7882384657859802
# Iteration: 181000, train loss: 0.10988730937242508
# Iteration: 182000, train loss: 0.3827968239784241
# Iteration: 183000, train loss: 0.2907419204711914
# Iteration: 184000, train loss: 0.45969441533088684
# Iteration: 185000, train loss: 0.6401706337928772
# Iteration: 186000, train loss: 0.39863309264183044
# Iteration: 187000, train loss: 0.18571391701698303
# Iteration: 188000, train loss: 0.5899813771247864
# Iteration: 189000, train loss: 0.254986047744751
# Iteration: 190000, train loss: 0.04942578077316284
# Iteration: 191000, train loss: 0.15118221938610077
# Iteration: 192000, train loss: 0.10310735553503036
# Iteration: 193000, train loss: 0.27131351828575134
# Iteration: 194000, train loss: 0.22940582036972046
# Iteration: 195000, train loss: 0.3340684771537781
# Iteration: 196000, train loss: 0.5595545172691345
# Iteration: 197000, train loss: 0.1628800481557846
# Iteration: 198000, train loss: 0.14290699362754822
# Iteration: 199000, train loss: 0.4796808660030365
# Iteration: 200000, train loss: 0.23327550292015076
# 2025-01-08 12:33:10, Iteration: 200000, Test Loss: 0.6890901327133179

# %%
torch.save(model.state_dict(), "/content/models/" + model.__class__.__name__ + ".pt")
