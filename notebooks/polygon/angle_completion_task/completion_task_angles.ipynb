# %%
import os
os.chdir('../../src')

# %%
from data import PolygonSentenceReader, Polygon
from modules import NLLLoss, ELBOLoss
from neural_process.models.np import CNP, LNP
from neural_process.models.attnnp import AttnCNP, AttnLNP
from utils import plot_polygon

import datetime
import random
import torch
import torch.nn as nn
from torch.distributions.kl import kl_divergence

# %%
TRAINING_ITERATIONS = int(2e5)
PLOT_AFTER = int(2e4)
BATCH_SIZE = 64
MAX_CONTEXT_POINTS = 10
MIN_SIDES = 3
MAX_SIDES = 8
x_size = 4 + 3 * MAX_SIDES
y_size = MAX_SIDES
torch.manual_seed(0)

criterion = ELBOLoss()

# Instantiate a polygon generator.
# (For example, polygons with between 3 and 8 sides.)
polygon_generator_train = PolygonSentenceReader(
    batch_size=BATCH_SIZE,
    max_num_context=MAX_CONTEXT_POINTS,
    max_seq_len=x_size,
    min_num_sides=MIN_SIDES,
    max_num_sides=MAX_SIDES,
    center=(5, 5),
    radius=3,
    testing=False,
)

polygon_generator_test = PolygonSentenceReader(
    batch_size=100,
    max_num_context=MAX_CONTEXT_POINTS,
    max_seq_len=x_size,
    min_num_sides=MIN_SIDES,
    max_num_sides=MIN_SIDES,
    center=(5, 5),
    radius=3,
    testing=True,
)

model = LNP(x_dim=x_size, y_dim=y_size)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=TRAINING_ITERATIONS, eta_min=1e-6
)
model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
device = next(model.parameters()).device

# %% [markdown]
# # Training

# %%
# ----------------------
# Training Loop
# ----------------------
for it in range(TRAINING_ITERATIONS + 1):
    # Generate a batch of polygon completion tasks.
    (
        context_x,
        context_y,
        target_x,
        target_y,
        tokens,
        true_poly,
        max_seq_len,
        num_context,
    ) = polygon_generator_train.generate_polygon_batch_few_shot_completion_task()

    context_x = context_x.to(device)
    context_y = context_y.to(device)
    target_x = target_x.to(device)
    target_y = target_y.to(device)

    optimizer.zero_grad()
    # Forward pass: the NP model expects context_x, context_y, target_x, target_y.
    dist, z, q_zc, q_zct = model(context_x, context_y, target_x, target_y)
    loss = criterion(dist, q_zct, q_zc, target_y)
    loss.backward()
    optimizer.step()
    scheduler.step()

    if it % 1000 == 0:
        print("Iteration: {}, train loss: {}".format(it, loss.item()))

    # ----------------------
    # Evaluation and Plotting
    # ----------------------
    if it % PLOT_AFTER == 0:
        # For plotting, we generate a single polygon sample.
        (
            context_x_eval,
            context_y_eval,
            target_x_eval,
            target_y_eval,
            tokens_eval,
            true_poly_eval,
            max_seq_len_eval,
            num_context_eval,
        ) = polygon_generator_test.generate_polygon_batch_few_shot_completion_task()

        context_x_eval = context_x_eval.to(device)
        context_y_eval = context_y_eval.to(device)
        target_x_eval = target_x_eval.to(device)
        target_y_eval = target_y_eval.to(device)

        # Forward pass through the model.
        test_dist, test_z, test_q_zc, test_q_zct = model(
            context_x_eval, context_y_eval, target_x_eval, target_y_eval
        )
        loss = criterion(dist, q_zct, q_zc, target_y)

        print(
            "{}, Iteration: {}, Test Loss: {}".format(
                datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
                it,
                loss.item(),
            )
        )

        # Get NP predictions on target tokens (taking the mean of the predictive distribution).
        pred_target = test_dist.mean  # shape: [n_z, batch, n_target, y_dim]

        # For simplicity, we average over latent samples and batch dimension.
        pred_target_avg = pred_target.mean(0).squeeze(1)  # shape: [n_target, y_dim]

        # print("pred_target_avg shape: ", pred_target_avg.shape)
        pred_target_avg = pred_target_avg[0]
        true_polygon = true_poly_eval[0]
        true_polygon_tokenised = true_polygon.to_tokenised()
        # print("pred_target_avg shape after squeeze: ", pred_target_avg.shape)

        print("True Polygon: ", true_polygon)
        print("True Polygon Angles: ", true_polygon.angles)
        print("Predicted Polygon Angles: ", pred_target_avg.tolist()[:len(true_polygon.angles)])
# Out:
# Iteration: 0, train loss: 1761.4365234375
# 2025-04-26 18:55:36, Iteration: 0, Test Loss: 1761.4365234375
# True Polygon:  Polygon(n=3, vertices=[(7.9, 5.77), (2.82, 7.06), (6.72, 2.54)], lengths=[5.241230771488697, 5.969958123806229, 3.438793393037738], angles=[84.17983457513594, 34.96297794566348, 60.85718747920056])
# True Polygon Angles:  [84.17983457513594, 34.96297794566348, 60.85718747920056]
# Predicted Polygon Angles:  [52.9559440612793, 17.04191780090332, 67.7646713256836]
# Iteration: 1000, train loss: 98.29766082763672
# Iteration: 2000, train loss: 161.7765655517578
# Iteration: 3000, train loss: 108.50579071044922
# Iteration: 4000, train loss: 22.380998611450195
# Iteration: 5000, train loss: 12.399890899658203
# Iteration: 6000, train loss: 22.51494598388672
# Iteration: 7000, train loss: 17.426193237304688
# Iteration: 8000, train loss: 11.972577095031738
# Iteration: 9000, train loss: 20.211105346679688
# Iteration: 10000, train loss: 7.135207176208496
# Iteration: 11000, train loss: 26.058134078979492
# Iteration: 12000, train loss: 16.115520477294922
# Iteration: 13000, train loss: 6.078106880187988
# Iteration: 14000, train loss: 6.582180500030518
# Iteration: 15000, train loss: 4.797299861907959
# Iteration: 16000, train loss: 7.259216785430908
# Iteration: 17000, train loss: 6.587893486022949
# Iteration: 18000, train loss: 5.183907508850098
# Iteration: 19000, train loss: 4.660715579986572
# Iteration: 20000, train loss: 4.8545122146606445
# 2025-04-26 19:03:24, Iteration: 20000, Test Loss: 4.8545122146606445
# True Polygon:  Polygon(n=3, vertices=[(2.16, 5.96), (2.61, 3.19), (7.96, 4.52)], lengths=[2.8063143088399776, 5.512839558702937, 5.976085675423337], angles=[66.82940188515701, 85.2667450368473, 27.903853077995702])
# True Polygon Angles:  [66.82940188515701, 85.2667450368473, 27.903853077995702]
# Predicted Polygon Angles:  [41.415382385253906, 71.34297943115234, 49.37604522705078]
# Iteration: 21000, train loss: 4.036046981811523
# Iteration: 22000, train loss: 4.9148454666137695
# Iteration: 23000, train loss: 5.199141502380371
# Iteration: 24000, train loss: 4.197826862335205
# Iteration: 25000, train loss: 4.299816131591797
# Iteration: 26000, train loss: 4.401278495788574
# Iteration: 27000, train loss: 4.698292255401611
# Iteration: 28000, train loss: 3.816201686859131
# Iteration: 29000, train loss: 3.7493534088134766
# Iteration: 30000, train loss: 3.7726142406463623
# Iteration: 31000, train loss: 3.892207622528076
# Iteration: 32000, train loss: 3.6674039363861084
# Iteration: 33000, train loss: 3.290482759475708
# Iteration: 34000, train loss: 3.215035915374756
# Iteration: 35000, train loss: 3.41676926612854
# Iteration: 36000, train loss: 3.0608510971069336
# Iteration: 37000, train loss: 2.7048516273498535
# Iteration: 38000, train loss: 3.186979055404663
# Iteration: 39000, train loss: 3.191368341445923
# Iteration: 40000, train loss: 3.1289401054382324
# 2025-04-26 19:11:14, Iteration: 40000, Test Loss: 3.1289401054382324
# True Polygon:  Polygon(n=3, vertices=[(6.62, 7.52), (5.42, 7.97), (8.0, 4.97)], lengths=[1.2816005617976298, 3.9568169025114113, 2.8994654679785374], angles=[138.97725444411032, 28.748423740924498, 12.274321814965134])
# True Polygon Angles:  [138.97725444411032, 28.748423740924498, 12.274321814965134]
# Predicted Polygon Angles:  [43.03969192504883, 81.4942855834961, 42.0076789855957]
# Iteration: 41000, train loss: 2.8031208515167236
# Iteration: 42000, train loss: 2.4412102699279785
# Iteration: 43000, train loss: 3.097957134246826
# Iteration: 44000, train loss: 2.875701904296875
# Iteration: 45000, train loss: 2.7110977172851562
# Iteration: 46000, train loss: 2.9936282634735107
# Iteration: 47000, train loss: 2.898956298828125
# Iteration: 48000, train loss: 2.9902443885803223
# Iteration: 49000, train loss: 2.522082567214966
# Iteration: 50000, train loss: 2.621227264404297
# Iteration: 51000, train loss: 2.5512149333953857
# Iteration: 52000, train loss: 2.3720500469207764
# Iteration: 53000, train loss: 2.5265607833862305
# Iteration: 54000, train loss: 2.5717713832855225
# Iteration: 55000, train loss: 2.3279061317443848
# Iteration: 56000, train loss: 2.25956392288208
# Iteration: 57000, train loss: 2.332304000854492
# Iteration: 58000, train loss: 2.407496690750122
# Iteration: 59000, train loss: 2.5353493690490723
# Iteration: 60000, train loss: 2.890629768371582
# 2025-04-26 19:19:05, Iteration: 60000, Test Loss: 2.890629768371582
# True Polygon:  Polygon(n=3, vertices=[(7.99, 5.26), (2.68, 6.9), (2.07, 5.66)], lengths=[5.5574904408374834, 1.3819189556555047, 5.93349812505237], angles=[13.297906252034135, 99.03084246436408, 67.67125128360182])
# True Polygon Angles:  [13.297906252034135, 99.03084246436408, 67.67125128360182]
# Predicted Polygon Angles:  [46.199581146240234, 93.71744537353516, 48.505226135253906]
# Iteration: 61000, train loss: 3.0800678730010986
# Iteration: 62000, train loss: 2.603116512298584
# Iteration: 63000, train loss: 2.311310052871704
# Iteration: 64000, train loss: 2.188002109527588
# Iteration: 65000, train loss: 1.8783762454986572
# Iteration: 66000, train loss: 2.4768500328063965
# Iteration: 67000, train loss: 2.139693021774292
# Iteration: 68000, train loss: 2.791475296020508
# Iteration: 69000, train loss: 2.1206018924713135
# Iteration: 70000, train loss: 2.3229174613952637
# Iteration: 71000, train loss: 2.542581081390381
# Iteration: 72000, train loss: 2.001530647277832
# Iteration: 73000, train loss: 2.3062708377838135
# Iteration: 74000, train loss: 2.5437724590301514
# Iteration: 75000, train loss: 2.4014534950256348
# Iteration: 76000, train loss: 2.778078317642212
# Iteration: 77000, train loss: 2.3315720558166504
# Iteration: 78000, train loss: 2.377936840057373
# Iteration: 79000, train loss: 1.8615440130233765
# Iteration: 80000, train loss: 2.188924789428711
# 2025-04-26 19:26:54, Iteration: 80000, Test Loss: 2.188924789428711
# True Polygon:  Polygon(n=3, vertices=[(7.62, 6.46), (6.46, 7.62), (5.58, 2.06)], lengths=[1.6404877323527904, 5.629209535982828, 4.849907215607326], angles=[110.12584608587237, 53.993792398755566, 15.88036151537207])
# True Polygon Angles:  [110.12584608587237, 53.993792398755566, 15.88036151537207]
# Predicted Polygon Angles:  [52.972679138183594, 90.52030944824219, 40.13032531738281]
# Iteration: 81000, train loss: 2.020171880722046
# Iteration: 82000, train loss: 2.26212739944458
# Iteration: 83000, train loss: 2.5394866466522217
# Iteration: 84000, train loss: 2.0500824451446533
# Iteration: 85000, train loss: 2.1841578483581543
# Iteration: 86000, train loss: 2.209381103515625
# Iteration: 87000, train loss: 2.0160093307495117
# Iteration: 88000, train loss: 1.8574317693710327
# Iteration: 89000, train loss: 2.2110800743103027
# Iteration: 90000, train loss: 2.0518741607666016
# Iteration: 91000, train loss: 2.2095465660095215
# Iteration: 92000, train loss: 2.0463452339172363
# Iteration: 93000, train loss: 1.9032608270645142
# Iteration: 94000, train loss: 2.0100059509277344
# Iteration: 95000, train loss: 2.2331371307373047
# Iteration: 96000, train loss: 2.200423002243042
# Iteration: 97000, train loss: 2.0433766841888428
# Iteration: 98000, train loss: 2.0951082706451416
# Iteration: 99000, train loss: 2.7197248935699463
# Iteration: 100000, train loss: 2.121131181716919
# 2025-04-26 19:34:44, Iteration: 100000, Test Loss: 2.121131181716919
# True Polygon:  Polygon(n=3, vertices=[(7.61, 6.48), (3.98, 2.18), (4.93, 2.0)], lengths=[5.627335070883909, 0.9669022701390247, 5.220421438926173], angles=[9.282124002399247, 60.55826883782709, 110.15960715977369])
# True Polygon Angles:  [9.282124002399247, 60.55826883782709, 110.15960715977369]
# Predicted Polygon Angles:  [37.10920715332031, 91.63970947265625, 53.425392150878906]
# Iteration: 101000, train loss: 2.0403168201446533
# Iteration: 102000, train loss: 1.6616536378860474
# Iteration: 103000, train loss: 2.24377703666687
# Iteration: 104000, train loss: 2.2770450115203857
# Iteration: 105000, train loss: 1.8303284645080566
# Iteration: 106000, train loss: 1.972603678703308
# Iteration: 107000, train loss: 1.9069534540176392
# Iteration: 108000, train loss: 1.9321681261062622
# Iteration: 109000, train loss: 2.0361642837524414
# Iteration: 110000, train loss: 1.896052360534668
# Iteration: 111000, train loss: 2.16162109375
# Iteration: 112000, train loss: 2.185603141784668
# Iteration: 113000, train loss: 1.7361760139465332
# Iteration: 114000, train loss: 1.9593400955200195
# Iteration: 115000, train loss: 2.250551462173462
# Iteration: 116000, train loss: 1.968208909034729
# Iteration: 117000, train loss: 2.795077323913574
# Iteration: 118000, train loss: 2.193692922592163
# Iteration: 119000, train loss: 2.135745048522949
# Iteration: 120000, train loss: 2.1871280670166016
# 2025-04-26 19:42:33, Iteration: 120000, Test Loss: 2.1871280670166016
# True Polygon:  Polygon(n=3, vertices=[(3.67, 7.69), (2.0, 4.88), (3.04, 2.73)], lengths=[3.268791825736231, 2.388325773423718, 4.9998499977499336], angles=[23.484545482417136, 123.46270209179949, 33.052752425783424])
# True Polygon Angles:  [23.484545482417136, 123.46270209179949, 33.052752425783424]
# Predicted Polygon Angles:  [34.73781967163086, 97.00311279296875, 48.33641052246094]
# Iteration: 121000, train loss: 1.999497652053833
# Iteration: 122000, train loss: 2.1576621532440186
# Iteration: 123000, train loss: 1.6932218074798584
# Iteration: 124000, train loss: 2.06768536567688
# Iteration: 125000, train loss: 2.090484142303467
# Iteration: 126000, train loss: 2.120716094970703
# Iteration: 127000, train loss: 1.766693353652954
# Iteration: 128000, train loss: 1.7294689416885376
# Iteration: 129000, train loss: 1.962435007095337
# Iteration: 130000, train loss: 2.129516124725342
# Iteration: 131000, train loss: 1.8493683338165283
# Iteration: 132000, train loss: 1.941352128982544
# Iteration: 133000, train loss: 2.069977045059204
# Iteration: 134000, train loss: 1.7892975807189941
# Iteration: 135000, train loss: 1.8726986646652222
# Iteration: 136000, train loss: 1.811640977859497
# Iteration: 137000, train loss: 1.9072718620300293
# Iteration: 138000, train loss: 1.7019225358963013
# Iteration: 139000, train loss: 1.9596651792526245
# Iteration: 140000, train loss: 1.9194879531860352
# 2025-04-26 19:50:30, Iteration: 140000, Test Loss: 1.9194879531860352
# True Polygon:  Polygon(n=3, vertices=[(2.43, 3.45), (2.73, 3.03), (6.27, 2.28)], lengths=[0.5161395160225578, 3.6185770684068617, 4.014286985256534], angles=[37.51699883064651, 137.49972918964056, 4.983271979712877])
# True Polygon Angles:  [37.51699883064651, 137.49972918964056, 4.983271979712877]
# Predicted Polygon Angles:  [38.59294509887695, 92.41423034667969, 36.83945083618164]
# Iteration: 141000, train loss: 1.9108953475952148
# Iteration: 142000, train loss: 1.6354857683181763
# Iteration: 143000, train loss: 1.8433791399002075
# Iteration: 144000, train loss: 1.7941900491714478
# Iteration: 145000, train loss: 1.6217352151870728
# Iteration: 146000, train loss: 1.9506001472473145
# Iteration: 147000, train loss: 1.8206562995910645
# Iteration: 148000, train loss: 1.6226212978363037
# Iteration: 149000, train loss: 1.8651883602142334
# Iteration: 150000, train loss: 1.8058031797409058
# Iteration: 151000, train loss: 1.9898903369903564
# Iteration: 152000, train loss: 1.7253446578979492
# Iteration: 153000, train loss: 1.495002031326294
# Iteration: 154000, train loss: 1.9427411556243896
# Iteration: 155000, train loss: 1.9694687128067017
# Iteration: 156000, train loss: 1.9578713178634644
# Iteration: 157000, train loss: 1.7505701780319214
# Iteration: 158000, train loss: 1.8864389657974243
# Iteration: 159000, train loss: 1.8395994901657104
# Iteration: 160000, train loss: 1.7200771570205688
# 2025-04-26 19:58:24, Iteration: 160000, Test Loss: 1.7200771570205688
# True Polygon:  Polygon(n=3, vertices=[(2.03, 5.41), (2.0, 4.99), (3.64, 2.32)], lengths=[0.4210700654285459, 3.1334485794408695, 3.4842789784975605], angles=[31.60673471045459, 144.3547971486922, 4.038468140853349])
# True Polygon Angles:  [31.60673471045459, 144.3547971486922, 4.038468140853349]
# Predicted Polygon Angles:  [38.395164489746094, 86.95574188232422, 33.334571838378906]
# Iteration: 161000, train loss: 1.9228780269622803
# Iteration: 162000, train loss: 1.7921844720840454
# Iteration: 163000, train loss: 1.8620585203170776
# Iteration: 164000, train loss: 1.5787874460220337
# Iteration: 165000, train loss: 2.1210522651672363
# Iteration: 166000, train loss: 1.5772162675857544
# Iteration: 167000, train loss: 1.9450209140777588
# Iteration: 168000, train loss: 1.6549781560897827
# Iteration: 169000, train loss: 1.8980052471160889
# Iteration: 170000, train loss: 1.540176272392273
# Iteration: 171000, train loss: 1.517855167388916
# Iteration: 172000, train loss: 1.7799636125564575
# Iteration: 173000, train loss: 1.4630045890808105
# Iteration: 174000, train loss: 1.5777477025985718
# Iteration: 175000, train loss: 1.765688419342041
# Iteration: 176000, train loss: 1.6065020561218262
# Iteration: 177000, train loss: 1.8323408365249634
# Iteration: 178000, train loss: 1.5537035465240479
# Iteration: 179000, train loss: 1.5798925161361694
# Iteration: 180000, train loss: 1.8319541215896606
# 2025-04-26 20:06:18, Iteration: 180000, Test Loss: 1.8319541215896606
# True Polygon:  Polygon(n=3, vertices=[(4.94, 8.0), (2.02, 5.3), (4.96, 2.0)], lengths=[3.976983781711965, 4.419683246568695, 6.000033333240741], angles=[47.43273588755703, 91.06011501123766, 41.507149101205336])
# True Polygon Angles:  [47.43273588755703, 91.06011501123766, 41.507149101205336]
# Predicted Polygon Angles:  [42.42989730834961, 84.71955871582031, 42.08494186401367]
# Iteration: 181000, train loss: 1.6501195430755615
# Iteration: 182000, train loss: 1.898093581199646
# Iteration: 183000, train loss: 1.7774484157562256
# Iteration: 184000, train loss: 1.9094336032867432
# Iteration: 185000, train loss: 2.0962798595428467
# Iteration: 186000, train loss: 1.9394372701644897
# Iteration: 187000, train loss: 1.7685033082962036
# Iteration: 188000, train loss: 1.952720284461975
# Iteration: 189000, train loss: 1.726779580116272
# Iteration: 190000, train loss: 1.8946183919906616
# Iteration: 191000, train loss: 1.6594592332839966
# Iteration: 192000, train loss: 1.6377004384994507
# Iteration: 193000, train loss: 1.7505662441253662
# Iteration: 194000, train loss: 1.6753562688827515
# Iteration: 195000, train loss: 1.7865581512451172
# Iteration: 196000, train loss: 1.8801501989364624
# Iteration: 197000, train loss: 1.6430104970932007
# Iteration: 198000, train loss: 1.701837182044983
# Iteration: 199000, train loss: 1.8109698295593262
# Iteration: 200000, train loss: 2.0512495040893555
# 2025-04-26 20:14:07, Iteration: 200000, Test Loss: 2.0512495040893555
# True Polygon:  Polygon(n=3, vertices=[(2.25, 6.2), (2.09, 4.27), (5.21, 2.01)], lengths=[1.9366207682455547, 3.8525316351718644, 5.130077972116993], angles=[39.97813443024911, 121.17895810865825, 18.84290746109261])
# True Polygon Angles:  [39.97813443024911, 121.17895810865825, 18.84290746109261]
# Predicted Polygon Angles:  [38.88243103027344, 87.75289154052734, 37.51211929321289]

# %%
torch.save(model.state_dict(), "../models/polygon/np/" + model.__class__.__name__ + "_angles_completion_task_squares_only.pt")
